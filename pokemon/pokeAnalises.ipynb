# %%
import pandas as pd

df = pd.read_csv("./pokemon.csv")
df
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
# Tipos de pokemons que existem
df["Type 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("./pokemon.csv")

print(df.head())
print(df.info())
print(df.describe())
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
# ...

# %%
df
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
# QUANTIDADE DE POKEMONS DE CADA TIPO

tipo_primario_counts = df['Type 1'].value_counts()
plt.figure(figsize=(12,6))
sns.barplot(x=tipo_primario_counts.index, y=tipo_primario_counts.values, palette="Set2")
plt.title("Quantidade de Pokémons por Tipo Primário")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("pokemon_por_tipo_primario.png")
plt.show()
# Out:
# C:\Users\rapha\AppData\Local\Temp\ipykernel_13516\2124406157.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=tipo_primario_counts.index, y=tipo_primario_counts.values, palette="Set2")

# %%
# TIPOS PRIMARIOS MAIS FORTES

forca_tipo = df.groupby("Type 1")["Attack"].mean().sort_values(ascending=False)
plt.figure(figsize=(12,6))
sns.barplot(x=forca_tipo.index, y=forca_tipo.values, palette="magma")
plt.title("Ataque Médio por Tipo Primário")
plt.xticks(rotation=45)
plt.savefig("ataque_medio_tipo.png")
plt.show()
# Out:
# C:\Users\rapha\AppData\Local\Temp\ipykernel_13516\4044816011.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=forca_tipo.index, y=forca_tipo.values, palette="magma")

# %%
# GRAFICO DE DISPERSAO DE ATAQUE VS DEFESA

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Attack', y='Defense', hue='Type 1')
plt.title("Ataque vs Defesa por Tipo")
plt.savefig("ataque_vs_defesa.png")
plt.show()

# %%
# QUANTIDADE DE POKEMON LENDARIOS 

plt.figure(figsize=(6,6))
sns.countplot(x='Legendary', data=df, palette='Set1')
plt.title("Pokémons Lendários vs Não Lendários")
plt.savefig("pokemon_lendarios.png")
plt.show()
# Out:
# C:\Users\rapha\AppData\Local\Temp\ipykernel_13516\1668800331.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Legendary', data=df, palette='Set1')

# %%
atributos = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
for atributo in atributos:
    top = df.loc[df[atributo].idxmax()]
    print(f"\nPokémon com maior {atributo}:")
    print(top[['Name', 'Type 1', 'Type 2', atributo]])
# Out:
# Pokémon com maior HP:
# Name      Blissey
# Type 1     Normal
# Type 2        NaN
# HP            255
# Name: 261, dtype: object
#
# Pokémon com maior Attack:
# Name      Mega Mewtwo X
# Type 1          Psychic
# Type 2         Fighting
# Attack              190
# Name: 163, dtype: object
#
# Pokémon com maior Defense:
# Name       Mega Steelix
# Type 1            Steel
# Type 2           Ground
# Defense             230
# Name: 224, dtype: object
#
# Pokémon com maior Sp. Atk:
# Name       Mega Mewtwo Y
# Type 1           Psychic
# Type 2               NaN
# Sp. Atk              194
# Name: 164, dtype: object
#
# Pokémon com maior Sp. Def:
# Name       Shuckle
# Type 1         Bug
# Type 2        Rock
# Sp. Def        230
# Name: 230, dtype: object
#
# Pokémon com maior Speed:
# Name      Deoxys Speed Forme
# Type 1               Psychic
# Type 2                   NaN
# Speed                    180
# Name: 431, dtype: object

# %%
atributos = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
top_pokemons = []

for atributo in atributos:
    top = df.loc[df[atributo].idxmax()]
    top_pokemons.append({
        'Atributo': atributo,
        'Nome': top['Name'],
        'Tipo 1': top['Type 1'],
        'Tipo 2': top['Type 2'],
        'Valor': top[atributo]
    })

df_top = pd.DataFrame(top_pokemons)
plt.figure(figsize=(12, 6))
sns.barplot(data=df_top, x='Atributo', y='Valor', hue='Tipo 1', dodge=False, palette='tab10')
for i, row in df_top.iterrows():
    plt.text(i, row['Valor'] + 1, row['Nome'], ha='center', fontsize=9)
plt.title("Pokémons com Maior Atributo por Categoria")
plt.ylabel("Valor do Atributo")
plt.tight_layout()
plt.savefig("maior_valor_por_atributo.png")
plt.show()

# %%
for atributo in ['Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']:
    media_tipo = df.groupby("Type 1")[atributo].mean().sort_values(ascending=False)
    plt.figure(figsize=(12,6))
    sns.barplot(x=media_tipo.index, y=media_tipo.values, palette="viridis")
    plt.title(f"{atributo} Médio por Tipo Primário")
    plt.xticks(rotation=45)
    plt.savefig(f"media_{atributo.lower()}_tipo.png")
    plt.show()
# Out:
# C:\Users\rapha\AppData\Local\Temp\ipykernel_13516\1257883171.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=media_tipo.index, y=media_tipo.values, palette="viridis")
# C:\Users\rapha\AppData\Local\Temp\ipykernel_13516\1257883171.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=media_tipo.index, y=media_tipo.values, palette="viridis")
# C:\Users\rapha\AppData\Local\Temp\ipykernel_13516\1257883171.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=media_tipo.index, y=media_tipo.values, palette="viridis")
# ...
